# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_csv('archive/olist_merge.csv',low_memory=False)

# %%
df
# Out:
#                       customer_unique_id order_status delai_livraison  \
# 0       7c396fd4830fd04220f754e42b4e5bff    delivered          8 days
# 1       7c396fd4830fd04220f754e42b4e5bff    delivered          8 days
# 2       af07308b275d755c9edb36a90c618231    delivered         14 days
# 3       3a653a41f6f9fc3d2a113cf8398680e8    delivered          9 days
# 4       7c142cf63193a1473d2e66489a9ae977    delivered         14 days
# ...                                  ...          ...             ...
# 116784  da62f9e57a76d978d02ab5362c509660    delivered         22 days
# 116785  737520a9aad80b3fbbdad19b66b37b30    delivered         25 days
# 116786  5097a5312c8b157bb7be58ae360ef43c    delivered         17 days
# 116787  5097a5312c8b157bb7be58ae360ef43c    delivered         17 days
# 116788  60350aa974b26ff12caad89e55993bd6    delivered          8 days
#
#        delais_respecter customer_state  payment_value  freight_value  \
# ...

# %%
df.isna().sum()
# Out:
# customer_unique_id                  0
# order_status                        0
# delai_livraison                  3322
# delais_respecter                    0
# customer_state                      0
# payment_value                       3
# freight_value                     800
# payment_type                        3
# payment_installments                3
# product_category_name_english    2483
# seller_state                      800
# review_score                      986
# product_weight_g                  819
# produit_volume_cm_cube            819
# dtype: int64

# %%
mode = df.mode().iloc[0]
df.fillna(mode, inplace=True)

# %%
df.isna().sum()
# Out:
# customer_unique_id               0
# order_status                     0
# delai_livraison                  0
# delais_respecter                 0
# customer_state                   0
# payment_value                    0
# freight_value                    0
# payment_type                     0
# payment_installments             0
# product_category_name_english    0
# seller_state                     0
# review_score                     0
# product_weight_g                 0
# produit_volume_cm_cube           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_unique_id', 'order_status', 'delai_livraison',
#        'delais_respecter', 'customer_state', 'payment_value', 'freight_value',
#        'payment_type', 'payment_installments', 'product_category_name_english',
#        'seller_state', 'review_score', 'product_weight_g',
#        'produit_volume_cm_cube'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116789 entries, 0 to 116788
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_unique_id             116789 non-null  object
#  1   order_status                   116789 non-null  object
#  2   delai_livraison                116789 non-null  object
#  3   delais_respecter               116789 non-null  object
#  4   customer_state                 116789 non-null  object
#  5   payment_value                  116789 non-null  float64
#  6   freight_value                  116789 non-null  float64
#  7   payment_type                   116789 non-null  object
#  8   payment_installments           116789 non-null  float64
#  9   product_category_name_english  116789 non-null  object
#  10  seller_state                   116789 non-null  object
#  11  review_score                   116789 non-null  float64
# ...

# %%
# def remove_word(string):
#     return string.replace("days", "").strip()

# df['delai_livraison'] = df['delai_livraison'].apply(remove_word)
# df['delai_livraison']=df['delai_livraison'].astype(int)

# %%
df
# Out:
#                       customer_unique_id order_status delai_livraison  \
# 0       7c396fd4830fd04220f754e42b4e5bff    delivered          8 days
# 1       7c396fd4830fd04220f754e42b4e5bff    delivered          8 days
# 2       af07308b275d755c9edb36a90c618231    delivered         14 days
# 3       3a653a41f6f9fc3d2a113cf8398680e8    delivered          9 days
# 4       7c142cf63193a1473d2e66489a9ae977    delivered         14 days
# ...                                  ...          ...             ...
# 116784  da62f9e57a76d978d02ab5362c509660    delivered         22 days
# 116785  737520a9aad80b3fbbdad19b66b37b30    delivered         25 days
# 116786  5097a5312c8b157bb7be58ae360ef43c    delivered         17 days
# 116787  5097a5312c8b157bb7be58ae360ef43c    delivered         17 days
# 116788  60350aa974b26ff12caad89e55993bd6    delivered          8 days
#
#        delais_respecter customer_state  payment_value  freight_value  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116789 entries, 0 to 116788
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_unique_id             116789 non-null  object
#  1   order_status                   116789 non-null  object
#  2   delai_livraison                116789 non-null  object
#  3   delais_respecter               116789 non-null  object
#  4   customer_state                 116789 non-null  object
#  5   payment_value                  116789 non-null  float64
#  6   freight_value                  116789 non-null  float64
#  7   payment_type                   116789 non-null  object
#  8   payment_installments           116789 non-null  float64
#  9   product_category_name_english  116789 non-null  object
#  10  seller_state                   116789 non-null  object
#  11  review_score                   116789 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# customer_unique_id               0
# order_status                     0
# delai_livraison                  0
# delais_respecter                 0
# customer_state                   0
# payment_value                    0
# freight_value                    0
# payment_type                     0
# payment_installments             0
# product_category_name_english    0
# seller_state                     0
# review_score                     0
# product_weight_g                 0
# produit_volume_cm_cube           0
# dtype: int64
